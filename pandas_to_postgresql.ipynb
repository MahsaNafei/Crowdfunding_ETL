# %%
# Import dependecies
import pandas as pd
from sqlalchemy import create_engine
import psycopg2

# %%
# Read contacts csv
contacts_df = pd.read_csv("../Crowdfunding_ETL/Output/contacts.csv")
contacts_df
# Out:
#      contact_id    first_name   last_name  \
# 0          4661       Cecilia     Velasco
# 1          3765       Mariana       Ellis
# 2          4187         Sofie       Woods
# 3          4941      Jeanette    Iannotti
# 4          2199        Samuel     Sorgatz
# ..          ...           ...         ...
# 995        3684       Whitney       Noack
# 996        5784     Gelsomina  Migliaccio
# 997        1498   Evangelista     Pereira
# 998        6073        Gareth     Comolli
# 999        4939  Michelangelo        Hess
#
#                                          email
# 0                 cecilia.velasco@rodrigues.fr
# 1                      mariana.ellis@rossi.org
# 2                      sofie.woods@riviere.com
# 3                  jeanette.iannotti@yahoo.com
# 4                     samuel.sorgatz@gmail.com
# ..                                         ...
# 995             whitney.noack@laboratorios.org
# 996              gelsomina.migliaccio@junk.com
# ...

# %%
# Create engine for SQL
engine = create_engine('postgresql://postgres:postgres@localhost:5432/df')

# %%
# import to sql
contacts_df.to_sql("contacts", con=engine.connect(), if_exists='replace')
# Out:
# 1000

# %%
contacts_df = pd.read_sql('SELECT * FROM contacts', con=engine.connect())
contacts_df.head(10)
# Out:
#    index  contact_id first_name last_name                         email
# 0      0        4661    Cecilia   Velasco  cecilia.velasco@rodrigues.fr
# 1      1        3765    Mariana     Ellis       mariana.ellis@rossi.org
# 2      2        4187      Sofie     Woods       sofie.woods@riviere.com
# 3      3        4941   Jeanette  Iannotti   jeanette.iannotti@yahoo.com
# 4      4        2199     Samuel   Sorgatz      samuel.sorgatz@gmail.com
# 5      5        5650    Socorro      Luna      socorro.luna@hotmail.com
# 6      6        5889   Carolina    Murray    carolina.murray@knight.com
# 7      7        4842      Kayla      Moon           kayla.moon@yahoo.de
# 8      8        3280    Ariadna    Geisel     ariadna.geisel@rangel.com
# 9      9        5468   Danielle    Ladeck  danielle.ladeck@scalfaro.net

# %%
# Read campaign csv
campaign_df = pd.read_csv("../Crowdfunding_ETL/Output/campaign.csv")
campaign_df
# Out:
#      cf_id  contact_id                company_name  \
# 0      147        4661  Baldwin, Riley and Jackson
# 1     1175        2288               Werner-Bryant
# 2      873        2067                 Stewart LLC
# 3     2568        5989              Castillo-Carey
# 4     1211        3307      Wright, Hartman and Yu
# ..     ...         ...                         ...
# 995    461        3521             Erickson-Rogers
# 996   1095        3565              Young and Sons
# 997   1388        4517             Valenzuela-Cook
# 998   2448        2389                  Little Ltd
# 999    602        2153                 Giles-Smith
#
#                                            description      goal  pledged  \
# 0                 Pre-emptive tertiary standardization     100.0      0.0
# 1                                Virtual uniform frame    1800.0   7991.0
# 2                   Cloned bi-directional architecture    1300.0  12047.0
# ...

# %%
# import to sql
campaign_df.to_sql("campaign", con=engine.connect(), if_exists='replace')
# Out:
# 1000

# %%
# Campaign data
campaign_df = pd.read_sql('SELECT * FROM campaign', con=engine.connect())
campaign_df.head(10)
# Out:
#    index  cf_id  contact_id                company_name  \
# 0      0    147        4661  Baldwin, Riley and Jackson
# 1      1   1175        2288               Werner-Bryant
# 2      2    873        2067                 Stewart LLC
# 3      3   2568        5989              Castillo-Carey
# 4      4   1211        3307      Wright, Hartman and Yu
# 5      5    990        3489             Morgan-Martinez
# 6      6   2228        4404          Alexander-Williams
# 7      7    509        1867            Mcknight-Freeman
# 8      8    966        4840                    Huff LLC
# 9      9   2765        5565                   Ho-Harris
#
#                                          description      goal   pledged  \
# 0               Pre-emptive tertiary standardization     100.0       0.0
# 1                              Virtual uniform frame    1800.0    7991.0
# 2                 Cloned bi-directional architecture    1300.0   12047.0
# ...

# %%
# Read category csv
category_df = pd.read_csv("../Crowdfunding_ETL/Output/category.csv")
category_df
# Out:
#   category_id      category
# 0        cat1          food
# 1        cat2         music
# 2        cat3    technology
# 3        cat4       theater
# 4        cat5  film & video
# 5        cat6    publishing
# 6        cat7         games
# 7        cat8   photography
# 8        cat9    journalism

# %%
# Import to sql
category_df.to_sql("category", con=engine.connect(), if_exists='replace')
# Out:
# 9

# %%
# Category data
campaign_df = pd.read_sql('SELECT * FROM category', con=engine.connect())
campaign_df.head(10)
# Out:
#    index category_id      category
# 0      0        cat1          food
# 1      1        cat2         music
# 2      2        cat3    technology
# 3      3        cat4       theater
# 4      4        cat5  film & video
# 5      5        cat6    publishing
# 6      6        cat7         games
# 7      7        cat8   photography
# 8      8        cat9    journalism

# %%
# Read category csv
subcategory_df = pd.read_csv("../Crowdfunding_ETL/Output/subcategory.csv")
subcategory_df
# Out:
#    subcategory_id        subcategory
# 0         subcat1        food trucks
# 1         subcat2               rock
# 2         subcat3                web
# 3         subcat4              plays
# 4         subcat5        documentary
# 5         subcat6     electric music
# 6         subcat7              drama
# 7         subcat8         indie rock
# 8         subcat9          wearables
# 9        subcat10         nonfiction
# 10       subcat11          animation
# 11       subcat12        video games
# 12       subcat13             shorts
# 13       subcat14            fiction
# 14       subcat15  photography books
# 15       subcat16   radio & podcasts
# 16       subcat17              metal
# 17       subcat18               jazz
# 18       subcat19       translations
# 19       subcat20         television
# 20       subcat21       mobile games
# 21       subcat22        world music
# 22       subcat23    science fiction
# 23       subcat24              audio

# %%
# Import to sql
subcategory_df.to_sql("subcategory", con=engine.connect(), if_exists='replace')
# Out:
# 24

# %%
# Subcategory data
subcategory_df = pd.read_sql('SELECT * FROM subcategory', con=engine.connect())
subcategory_df.head(10)
# Out:
#    index subcategory_id     subcategory
# 0      0        subcat1     food trucks
# 1      1        subcat2            rock
# 2      2        subcat3             web
# 3      3        subcat4           plays
# 4      4        subcat5     documentary
# 5      5        subcat6  electric music
# 6      6        subcat7           drama
# 7      7        subcat8      indie rock
# 8      8        subcat9       wearables
# 9      9       subcat10      nonfiction
